# %%
import sys
sys.path.append('../')

import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import wfdb
import pywt

from scripts.load_processed import load_processed_data
from scripts.load_data import load_record

# %%
signals, info, annotations = load_record('ice027_p_5of7')
# Out:
# Successfully loaded annotations for ice027_p_5of7

# %%
new_signals, info = load_processed_data('ice006_p_1of2')
# Out:
# Project root: /Users/ryanwelch/Desktop/6.7930/Innaccel
# Current working directory: /Users/ryanwelch/Desktop/6.7930/Innaccel/notebooks
# Looking for data in: /Users/ryanwelch/Desktop/6.7930/Innaccel/data/processed
# Directory exists: True
# Loaded processed signals with shape (72200, 16)
# Sampling rate: 20 Hz
# Processing steps: ['artifact_removal', 'filtering', 'downsampling']

# %%
plt.plot(signals[:,0])

# %%
plt.plot(new_signals[:,0])

# %%
fig = plot_signals_with_annotations(
            signals,
            annotated_contractions,
            fs=20,
            channel_idx=8
        )

# %%
preprocessed_signals = preprocess_signals(signals)

# %%
fig = plot_signals_with_annotations(
            preprocessed_signals,
            annotated_contractions,
            fs=20,
            channel_idx=8
        )
